# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./Myntra Fasion Clothing.csv", low_memory=False)

# %%
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %%
col = "Description"
allProds = []
cn = 0
for index, row in df.iterrows():
    if "lehenga" in row[col]:
        allProds.append(row)
        cn += 1
        if cn > 100:
            break

# %%
len(allProds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 len(allProds)
#
# NameError: name 'allProds' is not defined

# %%
allProds[:50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 allProds[:50]
#
# NameError: name 'allProds' is not defined

# %%
import requests
from bs4 import BeautifulSoup

URL = "https://www.nykaafashion.com/juniper-womens-fuchsia-printed-brocade-festive-wear-lehenga-choli-set-of-2/p/7731592"
# URL = "https://www.manyavar.com/mauve-shadow-purple-geometric-patterned-bridal-lehenga-ulb4532-413"
# URL = "https://realpython.github.io/fake-jobs/"
URL = "https://www.nykaafashion.com/readiprint-fashions-georgette-green-lehenga-choli-with-dupatta-set-of-3/p/9109142"

page = requests.get(URL)

soup = BeautifulSoup(page.text, "html.parser")

# %%
soup.find_all("div", class_="css-wibjj6")
# Out:
# []

# %%
soup
# Out:
# <!DOCTYPE html>
# ...
